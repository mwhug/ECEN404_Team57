# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/Shareddrives/Soybean hydroponics/datasets'
# Out:
# /content/drive/Shareddrives/Soybean hydroponics/datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#pandas has a read_excel() method for .xslx files
Potassium_data = pd.read_excel('Copy of K_Mary.xlsx')
Nitrogen_data = pd.read_excel('Copy of N_Mary.xlsx')
Magnesium_data = pd.read_excel('Copy of Mg_Mary.xlsx')

# %%
Kdf = pd.DataFrame(Potassium_data)
Ndf = pd.DataFrame(Nitrogen_data)
Mgdf = pd.DataFrame(Magnesium_data)

# %%
Kdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl No                      15 non-null     float64
#  1   Date                       15 non-null     datetime64[ns]
#  2   Conc of K                  15 non-null     float64
#  3   Ca                         15 non-null     float64
#  4   Mg                         15 non-null     float64
#  5   Na                         15 non-null     float64
#  6   K                          15 non-null     float64
#  7   B                          15 non-null     float64
#  8   CO_3                       15 non-null     float64
#  9   HCO_3                      15 non-null     float64
#  10  SO_4                       15 non-null     float64
#  11  Cl                         15 non-null     float64
#  12  NO3_N                      15 non-null     float64
# ...

# %%
Kdf.head(20)
# Out:
#     Sl No       Date  Conc of K     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 0     1.0 2022-04-29      200.0  118.0  28.0  12.0  278.0  0.32   0.0    8.0
# 1     NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 2     2.0 2022-05-02      200.0  117.0  30.0   9.0  229.0  0.31   0.0    3.0
# 3     NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 4     3.0 2022-05-06      200.0  117.0  30.0   3.0  136.0  0.29   0.0    0.0
# 5     NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 6     4.0 2022-05-16      200.0  111.0  32.0   3.0   67.0  0.38   0.0    0.0
# 7     NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 8     5.0 2022-05-18      200.0  119.0  39.0   2.0  171.0  0.34   0.0    0.0
# 9     6.0 2022-04-29      100.0   74.0  23.0  14.0  230.0  0.21   0.0    6.0
# 10    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# ...

# %%
Kdf.drop(columns=['Fe', 'Cu','As', 'Ba', 'Ni', 'Cd', 'Pb', 'Cr', 'F'], inplace=True)

# %%
Kdf[['SO_4', 'Cl', 'NO3_N', 'P']].head(15)
# Out:
#      SO_4   Cl  NO3_N       P
# 0   105.0  5.0  84.64   79.45
# 1     NaN  NaN    NaN     NaN
# 2   104.0  5.0  77.18   75.46
# 3     NaN  NaN    NaN     NaN
# 4   102.0  0.7  49.67   73.31
# 5     NaN  NaN    NaN     NaN
# 6   155.0  1.0  30.76   73.24
# 7     NaN  NaN    NaN     NaN
# 8   144.0  0.7  65.21  103.91
# 9    81.0  5.0  87.76   51.19
# 10    NaN  NaN    NaN     NaN
# 11  105.0  5.0  80.37   47.03
# 12    NaN  NaN    NaN     NaN
# 13  100.0  0.7  66.91   43.01
# 14    NaN  NaN    NaN     NaN

# %% [markdown]
# Split K data according to concentration

# %%
K200 = Kdf.iloc[0:9]
K100 = Kdf.iloc[9:18]
K300 = Kdf.iloc[18:]

# %% [markdown]
# **Linear interpolation: Potassium**

# %%
K100.head(9)
# Out:
#     Sl No       Date  Conc of K     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 9     6.0 2022-04-29      100.0   74.0  23.0  14.0  230.0  0.21   0.0    6.0
# 10    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 11    7.0 2022-05-02      100.0  114.0  30.0  10.0  230.0  0.31   0.0    9.0
# 12    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 13    8.0 2022-05-06      100.0  111.0  30.0   4.0  163.0  0.29   0.0    2.0
# 14    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 15    9.0 2022-05-16      100.0  152.0  30.0   3.0   50.0  0.40   0.0    8.0
# 16    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 17   10.0 2022-05-18      100.0  132.0  32.0   2.0  148.0  0.30   0.0    2.0
#
#     ...    pH  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  \
# 9   ...  5.12        1039.0                       16.0         278.0
# ...

# %%
nanval = np.nan
K100.loc[10] = ['6.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K100.loc[12] = ['7.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K100.loc[14] = ['8.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K100.loc[16] = ['9.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K100.head(9)
# Out:
# <ipython-input-130-a1b30aa6ea68>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   K100.loc[10] = ['6.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#    Sl No                 Date Conc of K     Ca    Mg    Na      K     B  CO_3  \
# 9    6.0  2022-04-29 00:00:00     100.0   74.0  23.0  14.0  230.0  0.21   0.0
# 10   6.5                 Date       100    NaN   NaN   NaN    NaN   NaN   0.0
# 11   7.0  2022-05-02 00:00:00     100.0  114.0  30.0  10.0  230.0  0.31   0.0
# 12   7.5                 Date       100    NaN   NaN   NaN    NaN   NaN   0.0
# 13   8.0  2022-05-06 00:00:00     100.0  111.0  30.0   4.0  163.0  0.29   0.0
# ...

# %%
for column in K100:
  K100[column] = K100[column].interpolate(method='linear')

K100.head(9)
# Out:
# <ipython-input-131-5618a9b33285>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   K100[column] = K100[column].interpolate(method='linear')
#    Sl No                 Date Conc of K     Ca    Mg    Na      K      B  \
# 9    6.0  2022-04-29 00:00:00     100.0   74.0  23.0  14.0  230.0  0.210
# 10   6.5                 Date       100   94.0  26.5  12.0  230.0  0.260
# 11   7.0  2022-05-02 00:00:00     100.0  114.0  30.0  10.0  230.0  0.310
# 12   7.5                 Date       100  112.5  30.0   7.0  196.5  0.300
# 13   8.0  2022-05-06 00:00:00     100.0  111.0  30.0   4.0  163.0  0.290
# 14   8.5                 Date       100  131.5  30.0   3.5  106.5  0.345
# 15   9.0  2022-05-16 00:00:00     100.0  152.0  30.0   3.0   50.0  0.400
# ...

# %% [markdown]
# K200

# %%
K200.head(9)
# Out:
#    Sl No       Date  Conc of K     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 0    1.0 2022-04-29      200.0  118.0  28.0  12.0  278.0  0.32   0.0    8.0
# 1    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 2    2.0 2022-05-02      200.0  117.0  30.0   9.0  229.0  0.31   0.0    3.0
# 3    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 4    3.0 2022-05-06      200.0  117.0  30.0   3.0  136.0  0.29   0.0    0.0
# 5    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 6    4.0 2022-05-16      200.0  111.0  32.0   3.0   67.0  0.38   0.0    0.0
# 7    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 8    5.0 2022-05-18      200.0  119.0  39.0   2.0  171.0  0.34   0.0    0.0
#
#    ...    pH  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  \
# 0  ...  5.07        1123.0                       24.0         408.0
# 1  ...   NaN           NaN                        NaN           NaN
# ...

# %%
nanval = np.nan
K200.loc[1] = ['1.5', 'Date', '200', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K200.loc[3] = ['2.5', 'Date', '200', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K200.loc[5] = ['3.5', 'Date', '200', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K200.loc[7] = ['4.5', 'Date', '200', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K200.head(9)

# %%
for column in K200:
  K200[column] = K200[column].interpolate(method='linear')

K200.head(9)
# Out:
# <ipython-input-134-30a51ed06c08>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   K200[column] = K200[column].interpolate(method='linear')
#   Sl No                 Date Conc of K     Ca    Mg    Na      K      B  CO_3  \
# 0   1.0  2022-04-29 00:00:00     200.0  118.0  28.0  12.0  278.0  0.320   0.0
# 1   1.5                 Date       200  117.5  29.0  10.5  253.5  0.315   0.0
# 2   2.0  2022-05-02 00:00:00     200.0  117.0  30.0   9.0  229.0  0.310   0.0
# 3   2.5                 Date       200  117.0  30.0   6.0  182.5  0.300   0.0
# 4   3.0  2022-05-06 00:00:00     200.0  117.0  30.0   3.0  136.0  0.290   0.0
# 5   3.5                 Date       200  114.0  31.0   3.0  101.5  0.335   0.0
# ...

# %%
K300.head(9)
# Out:
#     Sl No       Date  Conc of K     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 18   11.0 2022-04-29      300.0   72.0  21.0  13.0  301.0  0.24   0.0    7.0
# 19    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 20   12.0 2022-05-02      300.0  110.0  28.0   9.0  259.0  0.34   0.0  148.0
# 21    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 22   13.0 2022-05-06      300.0  110.0  28.0   3.0  187.0  0.33   0.0    0.0
# 23    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 24   14.0 2022-05-16      300.0  153.0  35.0   2.0  152.0  0.43   0.0    0.0
# 25    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 26   15.0 2022-05-18      300.0  163.0  39.0   2.0  275.0  0.38   0.0   11.0
#
#     ...    pH  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  \
# 18  ...  4.67        1182.0                       16.0         266.0
# ...

# %%
nanval = np.nan
K300.loc[19] = ['11.5', 'Date', '300', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K300.loc[21] = ['12.5', 'Date', '300', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K300.loc[23] = ['13.5', 'Date', '300', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K300.loc[25] = ['14.5', 'Date', '300', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
K300.head(9)
# Out:
# <ipython-input-136-06420402f21b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   K300.loc[19] = ['11.5', 'Date', '300', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#    Sl No                 Date Conc of K     Ca    Mg    Na      K     B  CO_3  \
# 18  11.0  2022-04-29 00:00:00     300.0   72.0  21.0  13.0  301.0  0.24   0.0
# 19  11.5                 Date       300    NaN   NaN   NaN    NaN   NaN   0.0
# 20  12.0  2022-05-02 00:00:00     300.0  110.0  28.0   9.0  259.0  0.34   0.0
# 21  12.5                 Date       300    NaN   NaN   NaN    NaN   NaN   0.0
# 22  13.0  2022-05-06 00:00:00     300.0  110.0  28.0   3.0  187.0  0.33   0.0
# ...

# %%
for column in K300:
  K300[column] = K300[column].interpolate(method='linear')

K300.head(9)
# Out:
# <ipython-input-137-a8e81ff31d2a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   K300[column] = K300[column].interpolate(method='linear')
#    Sl No                 Date Conc of K     Ca    Mg    Na      K      B  \
# 18  11.0  2022-04-29 00:00:00     300.0   72.0  21.0  13.0  301.0  0.240
# 19  11.5                 Date       300   91.0  24.5  11.0  280.0  0.290
# 20  12.0  2022-05-02 00:00:00     300.0  110.0  28.0   9.0  259.0  0.340
# 21  12.5                 Date       300  110.0  28.0   6.0  223.0  0.335
# 22  13.0  2022-05-06 00:00:00     300.0  110.0  28.0   3.0  187.0  0.330
# 23  13.5                 Date       300  131.5  31.5   2.5  169.5  0.380
# 24  14.0  2022-05-16 00:00:00     300.0  153.0  35.0   2.0  152.0  0.430
# ...

# %%
Ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl No                      15 non-null     float64
#  1   Date                       15 non-null     datetime64[ns]
#  2   Conc of N                  15 non-null     float64
#  3   Ca                         15 non-null     float64
#  4   Mg                         15 non-null     float64
#  5   Na                         15 non-null     float64
#  6   K                          15 non-null     float64
#  7   B                          15 non-null     float64
#  8   CO_3                       15 non-null     float64
#  9   HCO_3                      15 non-null     float64
#  10  SO_4                       15 non-null     float64
#  11  Cl                         15 non-null     float64
#  12  NO3_N                      15 non-null     float64
# ...

# %%
Ndf.head()
# Out:
#    Sl No       Date  Conc of N     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 0    1.0 2022-04-29      100.0   74.0  23.0  14.0  179.0  0.20   0.0    8.0
# 1    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 2    2.0 2022-05-02      100.0  123.0  31.0   9.0  194.0  0.35   0.0    8.0
# 3    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 4    3.0 2022-05-06      100.0  119.0  31.0   3.0  161.0  0.31   0.0    2.0
#
#    ...     Cu    Mn     As     Ba     Ni      Cd     Pb     Cr      F     CB
# 0  ...  0.005  0.17  0.004  0.001  0.003  0.0009  0.007  0.002  0.005  101.0
# 1  ...    NaN   NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 2  ...  0.005  0.28    NaN    NaN    NaN     NaN    NaN    NaN    NaN  112.0
# 3  ...    NaN   NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 4  ...  0.005  0.26    NaN    NaN    NaN     NaN    NaN    NaN    NaN  115.0
#
# [5 rows x 33 columns]

# %%
Ndf.drop(columns=['Cu','As', 'Ba', 'Ni', 'Cd', 'Pb', 'Cr', 'F'], inplace=True)

# %% [markdown]
# Split by concentration

# %%
N100 = Ndf.iloc[0:9]
N175 = Ndf.iloc[9:18]
N250 = Ndf.iloc[18:]

# %% [markdown]
# **Linear Interpolation of Nitrogen 100**

# %%
N100.head()
# Out:
#    Sl No       Date  Conc of N     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 0    1.0 2022-04-29      100.0   74.0  23.0  14.0  179.0  0.20   0.0    8.0
# 1    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 2    2.0 2022-05-02      100.0  123.0  31.0   9.0  194.0  0.35   0.0    8.0
# 3    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 4    3.0 2022-05-06      100.0  119.0  31.0   3.0  161.0  0.31   0.0    2.0
#
#    ...  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  Alkalinity  \
# 0  ...        1319.0                       16.0         278.0         6.0
# 1  ...           NaN                        NaN           NaN         NaN
# 2  ...        1350.0                       25.0         436.0         7.0
# 3  ...           NaN                        NaN           NaN         NaN
# 4  ...        1253.0                       25.0         425.0         2.0
#
#      TDS  SAR     Fe    Zn    Mn     CB
# ...

# %%
nanval = np.nan
N100.loc[1] = ['1.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N100.loc[3] = ['2.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N100.loc[5] = ['3.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N100.loc[7] = ['4.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N100.head(9)
# Out:
# <ipython-input-143-875974b165b7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N100.loc[1] = ['1.5', 'Date', '100', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#   Sl No                 Date Conc of N     Ca    Mg    Na      K     B  CO_3  \
# 0   1.0  2022-04-29 00:00:00     100.0   74.0  23.0  14.0  179.0  0.20   0.0
# 1   1.5                 Date       100    NaN   NaN   NaN    NaN   NaN   0.0
# 2   2.0  2022-05-02 00:00:00     100.0  123.0  31.0   9.0  194.0  0.35   0.0
# 3   2.5                 Date       100    NaN   NaN   NaN    NaN   NaN   0.0
# 4   3.0  2022-05-06 00:00:00     100.0  119.0  31.0   3.0  161.0  0.31   0.0
# ...

# %%
for column in N100:
  N100[column] = N100[column].interpolate(method='linear')

N100.head()
# Out:
# <ipython-input-144-cfad4e367273>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N100[column] = N100[column].interpolate(method='linear')
#   Sl No                 Date Conc of N     Ca    Mg    Na      K      B  CO_3  \
# 0   1.0  2022-04-29 00:00:00     100.0   74.0  23.0  14.0  179.0  0.200   0.0
# 1   1.5                 Date       100   98.5  27.0  11.5  186.5  0.275   0.0
# 2   2.0  2022-05-02 00:00:00     100.0  123.0  31.0   9.0  194.0  0.350   0.0
# 3   2.5                 Date       100  121.0  31.0   6.0  177.5  0.330   0.0
# 4   3.0  2022-05-06 00:00:00     100.0  119.0  31.0   3.0  161.0  0.310   0.0
#
#    HCO_3  ...  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  \
# ...

# %% [markdown]
# **Nitrogen 175**

# %%
N175.head(9)
# Out:
#     Sl No       Date  Conc of N     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 9     6.0 2022-04-29      175.0   74.0  24.0  14.0  193.0  0.18   0.0    7.0
# 10    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 11    7.0 2022-05-02      175.0  123.0  33.0   9.0  195.0  0.31   0.0    1.0
# 12    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 13    8.0 2022-05-06      175.0  115.0  32.0   3.0  116.0  0.26   0.0    0.0
# 14    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 15    9.0 2022-05-16      175.0  176.0  45.0   4.0   65.0  0.46   0.0    0.0
# 16    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 17   10.0 2022-05-18      175.0  151.0  38.0   3.0  100.0  0.36   0.0    0.0
#
#     ...  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  Alkalinity  \
# 9   ...        1618.0                       17.0         284.0         5.0
# ...

# %%
nanval = np.nan
N175.loc[10] = ['6.5', 'Date', '175', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N175.loc[12] = ['7.5', 'Date', '175', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N175.loc[14] = ['8.5', 'Date', '175', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N175.loc[16] = ['9.5', 'Date', '175', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N100.head(9)
# Out:
# <ipython-input-146-48f20dc39bb0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N175.loc[10] = ['6.5', 'Date', '175', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#   Sl No                 Date Conc of N     Ca    Mg    Na      K      B  CO_3  \
# 0   1.0  2022-04-29 00:00:00     100.0   74.0  23.0  14.0  179.0  0.200   0.0
# 1   1.5                 Date       100   98.5  27.0  11.5  186.5  0.275   0.0
# 2   2.0  2022-05-02 00:00:00     100.0  123.0  31.0   9.0  194.0  0.350   0.0
# 3   2.5                 Date       100  121.0  31.0   6.0  177.5  0.330   0.0
# 4   3.0  2022-05-06 00:00:00     100.0  119.0  31.0   3.0  161.0  0.310   0.0
# ...

# %%
for column in N175:
  N175[column] = N175[column].interpolate(method='linear')

N175.head()
# Out:
# <ipython-input-147-3d15b95347f4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N175[column] = N175[column].interpolate(method='linear')
#    Sl No                 Date Conc of N     Ca    Mg    Na      K      B  \
# 9    6.0  2022-04-29 00:00:00     175.0   74.0  24.0  14.0  193.0  0.180
# 10   6.5                 Date       175   98.5  28.5  11.5  194.0  0.245
# 11   7.0  2022-05-02 00:00:00     175.0  123.0  33.0   9.0  195.0  0.310
# 12   7.5                 Date       175  119.0  32.5   6.0  155.5  0.285
# 13   8.0  2022-05-06 00:00:00     175.0  115.0  32.0   3.0  116.0  0.260
#
#     CO_3  HCO_3  ...  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  \
# ...

# %% [markdown]
# **Nitrogen 250**

# %%
N250.head(9)
# Out:
#     Sl No       Date  Conc of N     Ca    Mg    Na      K     B  CO_3  HCO_3  \
# 18   11.0 2022-04-29      250.0   78.0  26.0  13.0  201.0  0.22   0.0    6.0
# 19    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 20   12.0 2022-05-02      250.0  126.0  35.0  10.0  206.0  0.36   0.0    2.0
# 21    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 22   13.0 2022-05-06      250.0  116.0  34.0   3.0  116.0  0.31   0.0    0.0
# 23    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 24   14.0 2022-05-16      250.0  148.0  40.0   3.0   79.0  0.37   0.0    0.0
# 25    NaN        NaT        NaN    NaN   NaN   NaN    NaN   NaN   NaN    NaN
# 26   15.0 2022-05-18      250.0  137.0  36.0   2.0  115.0  0.30   0.0    0.0
#
#     ...  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  Alkalinity  \
# 18  ...        1880.0                       18.0         301.0         5.0
# ...

# %%
nanval = np.nan
N250.loc[19] = ['11.5', 'Date', '250', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N250.loc[21] = ['12.5', 'Date', '250', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N250.loc[23] = ['13.5', 'Date', '250', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N250.loc[25] = ['14.5', 'Date', '250', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval, nanval]
N250.head(9)
# Out:
# <ipython-input-149-d58ad17d3548>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N250.loc[19] = ['11.5', 'Date', '250', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#    Sl No                 Date Conc of N     Ca    Mg    Na      K     B  CO_3  \
# 18  11.0  2022-04-29 00:00:00     250.0   78.0  26.0  13.0  201.0  0.22   0.0
# 19  11.5                 Date       250    NaN   NaN   NaN    NaN   NaN   0.0
# 20  12.0  2022-05-02 00:00:00     250.0  126.0  35.0  10.0  206.0  0.36   0.0
# 21  12.5                 Date       250    NaN   NaN   NaN    NaN   NaN   0.0
# 22  13.0  2022-05-06 00:00:00     250.0  116.0  34.0   3.0  116.0  0.31   0.0
# ...

# %%
for column in N250:
  N250[column] = N250[column].interpolate(method='linear')

N250.head()
# Out:
# <ipython-input-150-ad1de5ff69a1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   N250[column] = N250[column].interpolate(method='linear')
#    Sl No                 Date Conc of N     Ca    Mg    Na      K      B  \
# 18  11.0  2022-04-29 00:00:00     250.0   78.0  26.0  13.0  201.0  0.220
# 19  11.5                 Date       250  102.0  30.5  11.5  203.5  0.290
# 20  12.0  2022-05-02 00:00:00     250.0  126.0  35.0  10.0  206.0  0.360
# 21  12.5                 Date       250  121.0  34.5   6.5  161.0  0.335
# 22  13.0  2022-05-06 00:00:00     250.0  116.0  34.0   3.0  116.0  0.310
#
#     CO_3  HCO_3  ...  Conductivity  Hardness_grains of CACO_3  Hardness_ppm  \
# ...

# %% [markdown]
# # Magnesium

# %%
Mgdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sl No                      15 non-null     float64
#  1   Date                       15 non-null     datetime64[ns]
#  2   Conc of Mg                 15 non-null     float64
#  3   Ca                         15 non-null     float64
#  4   Mg                         15 non-null     float64
#  5   Na                         15 non-null     float64
#  6   K                          15 non-null     float64
#  7   B                          15 non-null     float64
#  8   CO_3                       15 non-null     float64
#  9   HCO_3                      15 non-null     float64
#  10  SO_4                       15 non-null     float64
#  11  Cl                         15 non-null     float64
#  12  NO3_N                      15 non-null     float64
# ...

# %%
Mgdf.head(25)
# Out:
#     Sl No       Date  Conc of Mg     Ca     Mg    Na      K     B  CO_3  \
# 0     1.0 2022-04-29        30.0   74.0   49.0  14.0  181.0  0.25   0.0
# 1     NaN        NaT         NaN    NaN    NaN   NaN    NaN   NaN   NaN
# 2     2.0 2022-05-02        30.0  111.0   66.0   9.0  168.0  0.32   0.0
# 3     NaN        NaT         NaN    NaN    NaN   NaN    NaN   NaN   NaN
# 4     3.0 2022-05-06        30.0  111.0   66.0   3.0   94.0  0.31   0.0
# 5     NaN        NaT         NaN    NaN    NaN   NaN    NaN   NaN   NaN
# 6     4.0 2022-05-16        30.0  138.0   71.0   3.0   26.0  0.44   0.0
# 7     NaN        NaT         NaN    NaN    NaN   NaN    NaN   NaN   NaN
# 8     5.0 2022-05-18        30.0  147.0   87.0   4.0   81.0  0.43   0.0
# 9     6.0 2022-04-29        50.0   70.0   70.0  14.0  176.0  0.32   0.0
# 10    NaN        NaT         NaN    NaN    NaN   NaN    NaN   NaN   NaN
# 11    7.0 2022-05-02        50.0  111.0   98.0   8.0  144.0  0.43   0.0
# ...

# %%
Mgdf.drop(columns=['Fe', 'Cu','As', 'Ba', 'Ni', 'Cd', 'Pb', 'Cr', 'F'], inplace=True)

# %%
Mg30 = Mgdf.iloc[0:9]
Mg50 = Mgdf.iloc[9:18]
Mg70 = Mgdf.iloc[18:]

# %% [markdown]
# # Linear Interpolation of Magnesium

# %% [markdown]
# ****

# %%
Mg30.loc[1] = ['1.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg30.loc[3] = ['2.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg30.loc[5] = ['3.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg30.loc[7] = ['4.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg30.head(9)
# Out:
# <ipython-input-155-d358f32a6e4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mg30.loc[1] = ['1.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#   Sl No                 Date Conc of Mg     Ca    Mg    Na      K     B  CO_3  \
# 0   1.0  2022-04-29 00:00:00       30.0   74.0  49.0  14.0  181.0  0.25   0.0
# 1   1.5                 Date         50    NaN   NaN   NaN    NaN   NaN   0.0
# 2   2.0  2022-05-02 00:00:00       30.0  111.0  66.0   9.0  168.0  0.32   0.0
# 3   2.5                 Date         50    NaN   NaN   NaN    NaN   NaN   0.0
# 4   3.0  2022-05-06 00:00:00       30.0  111.0  66.0   3.0   94.0  0.31   0.0
# ...

# %%
for column in Mg30:
  Mg30[column] = Mg30[column].interpolate(method='linear')

Mg30.head(9)
# Out:
# <ipython-input-157-0f1bccc01cb5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mg30[column] = Mg30[column].interpolate(method='linear')
#   Sl No                 Date Conc of Mg     Ca    Mg    Na      K      B  \
# 0   1.0  2022-04-29 00:00:00       30.0   74.0  49.0  14.0  181.0  0.250
# 1   1.5                 Date         50   92.5  57.5  11.5  174.5  0.285
# 2   2.0  2022-05-02 00:00:00       30.0  111.0  66.0   9.0  168.0  0.320
# 3   2.5                 Date         50  111.0  66.0   6.0  131.0  0.315
# 4   3.0  2022-05-06 00:00:00       30.0  111.0  66.0   3.0   94.0  0.310
# 5   3.5                 Date         50  124.5  68.5   3.0   60.0  0.375
# 6   4.0  2022-05-16 00:00:00       30.0  138.0  71.0   3.0   26.0  0.440
# ...

# %% [markdown]
# **Magnesium 50**

# %%
Mg50.loc[10] = ['6.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg50.loc[12] = ['7.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg50.loc[14] = ['8.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg50.loc[16] = ['9.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg50.head(9)
# Out:
# <ipython-input-158-3456f5702342>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mg50.loc[10] = ['6.5', 'Date', '50', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#    Sl No                 Date Conc of Mg     Ca     Mg    Na      K     B  \
# 9    6.0  2022-04-29 00:00:00       50.0   70.0   70.0  14.0  176.0  0.32
# 10   6.5                 Date         50    NaN    NaN   NaN    NaN   NaN
# 11   7.0  2022-05-02 00:00:00       50.0  111.0   98.0   8.0  144.0  0.43
# 12   7.5                 Date         50    NaN    NaN   NaN    NaN   NaN
# 13   8.0  2022-05-06 00:00:00       50.0  109.0   98.0   3.0   79.0  0.41
# ...

# %%
for column in Mg50:
  Mg50[column] = Mg50[column].interpolate(method='linear')

Mg50.head(9)
# Out:
# <ipython-input-159-f13e1b2bcbe5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mg50[column] = Mg50[column].interpolate(method='linear')
#    Sl No                 Date Conc of Mg     Ca     Mg    Na      K      B  \
# 9    6.0  2022-04-29 00:00:00       50.0   70.0   70.0  14.0  176.0  0.320
# 10   6.5                 Date         50   90.5   84.0  11.0  160.0  0.375
# 11   7.0  2022-05-02 00:00:00       50.0  111.0   98.0   8.0  144.0  0.430
# 12   7.5                 Date         50  110.0   98.0   5.5  111.5  0.420
# 13   8.0  2022-05-06 00:00:00       50.0  109.0   98.0   3.0   79.0  0.410
# 14   8.5                 Date         50  118.0  105.0   3.0   45.5  0.465
# ...

# %% [markdown]
# **Magnesium 70**

# %%
Mg70.loc[19] = ['11.5', 'Date', '70', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg70.loc[21] = ['12.5', 'Date', '70', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg70.loc[23] = ['13.5', 'Date', '70', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg70.loc[25] = ['14.5', 'Date', '70', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
                 nanval, nanval, nanval, nanval]
Mg70.head(9)
# Out:
# <ipython-input-161-14fc90cd4f04>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mg70.loc[19] = ['11.5', 'Date', '70', nanval, nanval, nanval, nanval, nanval, 0, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval, nanval,
#    Sl No                 Date Conc of Mg     Ca     Mg    Na      K     B  \
# 18  11.0  2022-04-29 00:00:00       70.0   72.0   88.0  13.0  179.0  0.23
# 19  11.5                 Date         70    NaN    NaN   NaN    NaN   NaN
# 20  12.0  2022-05-02 00:00:00       70.0  124.0  135.0   8.0  168.0  0.32
# 21  12.5                 Date         70    NaN    NaN   NaN    NaN   NaN
# 22  13.0  2022-05-06 00:00:00       70.0  118.0  133.0   3.0  127.0  0.31
# ...

# %%
for column in Mg70:
  Mg70[column] = Mg70[column].interpolate(method='linear')

Mg70.head()
# Out:
# <ipython-input-162-5cf6db3367ed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mg70[column] = Mg70[column].interpolate(method='linear')
#    Sl No                 Date Conc of Mg     Ca     Mg    Na      K      B  \
# 18  11.0  2022-04-29 00:00:00       70.0   72.0   88.0  13.0  179.0  0.230
# 19  11.5                 Date         70   98.0  111.5  10.5  173.5  0.275
# 20  12.0  2022-05-02 00:00:00       70.0  124.0  135.0   8.0  168.0  0.320
# 21  12.5                 Date         70  121.0  134.0   5.5  147.5  0.315
# 22  13.0  2022-05-06 00:00:00       70.0  118.0  133.0   3.0  127.0  0.310
#
#     CO_3  HCO_3  ...     pH  Conductivity  Hardness_grains of CACO_3  \
# ...

# %% [markdown]
# # Combine all interpolated data into K, N, and Mg dataframes again

# %%
K_new = pd.concat([K100, K200, K300])

# %%
N_new = pd.concat([N100, N175, N250])

# %%
Mg_new = pd.concat([Mg30, Mg50, Mg70])

# %% [markdown]
# # Push this to CSV files for use on UI

# %%
# %cd '/content/drive/Shareddrives/Capstone Project'

# %%
K_new.to_csv('/content/drive/Shareddrives/Capstone Project/Interpolated_K.csv')

# %%
N_new.to_csv('/content/drive/Shareddrives/Capstone Project/Interpolated_N.csv')

# %%
Mg_new.to_csv('/content/drive/Shareddrives/Capstone Project/Interpolated_Mg.csv')
